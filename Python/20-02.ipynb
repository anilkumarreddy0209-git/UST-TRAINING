# %%
print("Hi")
# Out:
# Hi

# %%
import os
os.getenv("Home")

# %%
os.getenv("C:/Users/Administrator")

# %%
import os
os.getenv("C:/Users/Administrator/Desktop/Sample.txt")
lst=open("Sample.txt","w")
lst.write("THis is sample file")
lst.write(" Good morning to all")
lst.close()

# %%
lst=open("Sample.txt","r")
c=lst.read()
b=c[5:15:]
f=lst.tell()
print(c)
print(b)
print(f)
lst.close()
# Out:
# THis is sample file Good morning to all
# is sample
# 39

# %%
lst=open("Sample.txt","r")
a=lst.tell()
b=lst.seek(5)
c=lst.tell()
f=lst.read()
print(a)
print(b)
print(c)
print(f)
lst.close()
# Out:
# 0
# 5
# 5
# is sample file Good morning to all

# %%
lst=open("Sample.txt","r")
f=lst.readline()
print(f)
lst.close()
# Out:
# THis is sample file Good morning to all

# %%
a=open("Sample.txt","r")
for i in a:
    print(i)
a.close()
# Out:
# THis is sample file Good morning to all

# %%
import os 
os.rename("Example.txt","Demo.txt")
#os.remove("Filename")

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\307497'

# %%
os.chdir("C:/Users/Administrator/Desktop")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
os.listdir(os.getcwd())
# Out:
# ['desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'Readme - Shortcut.lnk',
#  'Sample.txt.txt',
#  'UST',
#  'ust_global_training']

# %%
os.listdir(os.getcwd())
# Out:
# ['Basic',
#  'desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'Readme - Shortcut.lnk',
#  'Sample.txt.txt',
#  'UST',
#  'ust_global_training']

# %%
os.mkdir("Normal")
os.listdir(os.getcwd())
# Out:
# ['Basic',
#  'desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'Normal',
#  'Readme - Shortcut.lnk',
#  'Sample.txt.txt',
#  'UST',
#  'ust_global_training']

# %%
os.chdir('C:/Users/Administrator/307497')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\307497'

# %%
os.remove("Demo.txt")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\307497'

# %%
os.chdir("C:/Users/Administrator/Desktop")
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
os.mkdir("Training")

# %%
os.listdir(os.getcwd())
# Out:
# ['Basic',
#  'desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'Normal',
#  'Readme - Shortcut.lnk',
#  'Sample.txt.txt',
#  'Training',
#  'UST',
#  'ust_global_training']

# %%
os.mkdir("Mydirectory")

# %%
os.listdir(os.getcwd())
# Out:
# ['Basic',
#  'desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'Mydirectory',
#  'Normal',
#  'Readme - Shortcut.lnk',
#  'Sample.txt',
#  'Sample.txt.txt',
#  'Training',
#  'UST',
#  'ust_global_training']

# %%
os.getenv("C:/Users/Administrator")
a=open("C:/Users/Administrator/Desktop/Mydirectory/Myfile.txt","w+")
a.write("Welcome to the data engineering")
a.write(" Welcome to the UST Global")
a.seek(0)
b=a.read()
print(b)
a.close()
# Out:
# Welcome to the data engineering Welcome to the UST Global

# %%
"""Delete the empyt directoyr"""
import os
os.rmdir("C:/Users/Administrator/Desktop/Training")

# %%
"""Delete the non empty directory"""

import shutil
shutil.rmtree("C:/Users/Administrator/Desktop/Normal")

# %%
import os
os.getenv("Home")

# %%
#MOdules and packages

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import datetime as dt
print(dt.datetime.now())
# Out:
# 2026-02-20 11:44:03.987154

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 11, 46, 22, 819081)

# %%
from math import pi
print(pi)
# Out:
# 3.141592653589793
