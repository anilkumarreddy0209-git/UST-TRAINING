# %%
#Local variable and global variable

# %%
def first(n):
    print(n)
first(10)
# Out:
# 10

# %%
def get_sum(name):
    a=10
    print(a)
get_sum("king")
print(a)  #This cannnot call outside the function because it is a local variable
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3     print(a)
#       4 get_sum("king")
# ----> 5 print(a)
#
# NameError: name 'a' is not defined

# %%
import math
def fact(a):
    b=math.factorial(a)
    print(b)
fact(5)
# Out:
# 120

# %%
def fact(n):
    fact=1
    a=[fact*=i for i in range(1,n+1)]
    print(fact) 
fact(5)
# Out:
#   Cell In[13], line 3
#     a=[fact*=i for i in range(1,n+1)]
#            ^
# SyntaxError: invalid syntax

# %%
lst=[1,2,3,-4,5,0,6]
print(all(lst)) #It will print False if 0 is exist in the list
print(abs(-4))
# Out:
# False
# 4

# %%
lst=[10,20,30,40]
for i,v in enumerate(lst,start=0):
    print("Index {0} has value {1}".format(i,v))
# Out:
# Index 0 has value 10
# Index 1 has value 20
# Index 2 has value 30
# Index 3 has value 40

# %%
n=10
if n>0:
    print("Positive")
else:
    print("NEgative")
# Out:
# Positive

# %%
lst=[-9,10,-4,3,5,6,-1,-2]
lst2=list(filter(lambda n:n>0,lst))
print(lst2)
# Out:
# [10, 3, 5, 6]

# %%
n=10
a=["Positive" for i in range(0,10) if n>0]
print(a)
# Out:
# ['Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive']

# %%
def show(n):
    return(n**2)
print(show(10))
# Out:
# 100

# %%
s=list(map(lambda x:x**2,[1,2,3,4,5]))
print(s)
# Out:
# [1, 4, 9, 16, 25]

# %%
from functools import reduce
#Reduce 
lst=[10,20,30]
p=reduce(lambda x,y:x*y,lst)
print(p)
# Out:
# 6000

# %%
n=10
a=["positive" if n>0 else "Negative"]
print(a)
# Out:
# ['positive']

# %%
#DIvmod
print(divmod(5,2))
# Out:
# (2, 1)

# %%
#Default Arguments
# def say(x,y):
# def say(x=1,y):  #error
# def say(x,y=1):
def say(x=1,y=1):
    prod=x+y
    # prod=x+y+z
    print(prod)
    
say(1)
# Out:
# 3

# %%
#KeyWord Argumetns
def lst(**kwargs):
    if kwargs:
        print("Contacts {0},{1},{2}".format(kwargs['name'],kwargs['phno'],kwargs['Course']))

lst(name="King",phno=193847757,Course="Cse",age=21)
# Out:
# Contacts King,193847757,Cse

# %%
#Arbitary
def lst(*name):
    print(name)
    for lst2 in name:
        print("name {0}".format(lst2))
lst('toy','joy','tim')
# Out:
# ('toy', 'joy', 'tim')
# name toy
# name joy
# name tim

# %%
#Class & objects
class Hello:
    name="Jack"
    age=20
print(Hello.name)
print(Hello.age)
Hello.name="king"
print(Hello.name)
print(Hello.age)
# Out:
# Jack
# 20
# king
# 20

# %%
#Ojects
class Hello:
    name="Tom"
    age="25"
p1=Hello()
p2=Hello()
print(Hello.name)
print(Hello.age)
p1.name="Jhon"
p1.age=30
print(p1.name)
print(p1.age)
p2.name="Brook"
p2.age=35
print(p2.name)
print(p2.age)
print(Hello.name)
print(Hello.age)
# Out:
# Tom
# 25
# Jhon
# 30
# Brook
# 35
# Tom
# 25

# %%
class Student:
    def __init__(self,name,age,course):
        self.name=name
        self.age=age
        self.course=course
p1=Student("King",20,"CSE")
print(p1.name,p1.age,p1.course)
p2=Student("Jack",30,"EEE")
print(p2.name,p2.age,p2.course)
# Out:
# King 20 CSE
# Jack 30 EEE

# %%
class member:
    def __init__(self,name,age,position):
        self.name=name
        self.age=age
        self.position=position
    def hi(self,name,age):
        self.name=name
        self.age=age 
test=member("Joe",20,"Officer")
test=member("King",40,"Manager")
print(test.name)
print(test.age)
print(test.position)
# Out:
# King
# 40
# Manager

# %%
class Show:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def hello(self):
        print("My name is",self.name)
p1=Show("Brace",30)
print(p1.name)
print(p1.age)
p1.hello()
# Out:
# Brace
# 30
# My name is Brace

# %%
class Track:
    def __init__(obj,name,age):
        obj.name=name
        obj.age=age
    def func(obj1):
        print("My name is ",obj1.name)
p1=Track("Brook",30)
p1.func()
# Out:
# My name is  Brook

# %%
class abc:
    print("Good Morning")
class xyz(abc):
    print("Good Afternoon")

p1=xyz()
# Out:
# Good Morning
# Good Afternoon

# %%
#Inheritance
class Sports:
    def __init__(self,model,color,cost):
        self.__model=model
        self.__color=color
        self.__cost=cost
    def getmodel(self):
        return self.__model
    def setmodel(self,model):
        self.__moodel=model
    def getcolor(self):
        return self.__color
    def setcolor(self,color):
        self.__color=color
    def getcost(self):
        return self.__cost
    def setcost(self,cost):
        self.__cost=cost

class Shoes(Sports):
    def __inti__(self,model,color,cost,brand):
        super().__init__(model,color,cost)
        # self.__brand=brand

s1=Shoes("Nike","Blue",300,"Brand")
# s1.setmodel("Nike")
print(s1.getmodel())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 25
#      22         super().__init__(model,color,cost)
#      23         # self.__brand=brand
# ---> 25 s1=Shoes("Nike","Blue",300,"Brand")
#      26 # s1.setmodel("Nike")
#      27 print(s1.getmodel())
#
# TypeError: Sports.__init__() takes 4 positional arguments but 5 were given

# %%
#Exception Handling
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
import sys
lst=['b',2,0]
for i in lst:
    try:
        print("Value is:",i)
        k=1/int(i)
    except:
        print("The error is",sys.exc_info(),"Occured")
        print("------------------")

print("The correct output",k)
# Out:
# Value is: b
# The error is (<class 'ValueError'>, ValueError("invalid literal for int() with base 10: 'b'"), <traceback object at 0x000001E453C12440>) Occured
# ------------------
# Value is: 2
# Value is: 0
# The error is (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x000001E453C217C0>) Occured
# ------------------
# The correct output 0.5

# %%
import sys
lit=[1,2,3,4,-4,5,0,'b']
for i in lit:
    try:
        k=1/i
    except:
        print("The error is",sys.exc_info())

print(k)
# Out:
# The error is (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x000001E454275BC0>)
# The error is (<class 'TypeError'>, TypeError("unsupported operand type(s) for /: 'int' and 'str'"), <traceback object at 0x000001E454275BC0>)
# 0.2

# %%
import sys
lst=['b',0,2]
for i in lst:
    try:
        print("------------")
        print("Value is:",i)
        k=1/int(i)
    except(ValueEror):
        print("This is ValueError")
    except(ZeroDivisionError):
        print("THis is zerodivision error")
    except:
        print("Other Error")
# Out:
# ------------
# Value is: b
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 7
#       6     print("Value is:",i)
# ----> 7     k=1/int(i)
#       8 except(ValueEror):
#
# ValueError: invalid literal for int() with base 10: 'b'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 8
#       6     print("Value is:",i)
#       7     k=1/int(i)
# ----> 8 except(ValueEror):
#       9     print("This is ValueError")
#      10 except(ZeroDivisionError):
#
# NameError: name 'ValueEror' is not defined

# %%
raise KeyboardInterupt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 raise KeyboardInterupt
#
# NameError: name 'KeyboardInterupt' is not defined

# %%
raise MemoryError("THis is memory error")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 raise MemoryError("THis is memory error")
#
# MemoryError: THis is memory error

# %%
try:
    n=10
    if n<=0:
        raise ValueError("Entered negative number")
except ValueError as e:
    print(e)
print(n)
# Out:
# 10

# %%
try:
    n=-9
    if n<=0:
        raise MemoryError("Entered negative number")
except MemoryError as e:
    print(e)
# Out:
# Entered negative number

# %%
lit=[1,2,3,4,-4,5,0,'b']
for i in lit:
    try:
        k=1/i
    except:
        print("The error is")
    finally:
        print("Closed")
# Out:
# Closed
# Closed
# Closed
# Closed
# Closed
# Closed
# The error is
# Closed
# The error is
# Closed

# %%
import logging
logging.basicConfig(level=logging.INFO)
logging.debug("THis is a debug mesage")
logging.info("App Started")
logging.warning("THis is a warning")
logging.error("A error")
logging.critical("Critical issue")
# Out:
# INFO:root:App Started
# WARNING:root:THis is a warning
# ERROR:root:A error
# CRITICAL:root:Critical issue

# %%
import logging
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s-%(levelname)s-%(message)s')

# %%
import logging
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s-%(levelname)s-%(message)s')

# %%
import sys
try:
    n1=int(input("Enter the first digit"))
    n2=int(input("Enter the second number"))
    c=input("Enter the operation")
    if c=='+':
        print("THe sum of two numbers is:",n1+n2)
    elif c=='*':
        print("THe Product of two numbers is",n1*n2)
    elif c=='/':
        print("The division of two numbers is",n1/n2)
        # if n1/0:
        #     raise ZeroDivisionError("The number is not divisible by zero")
    elif c=='-':
        print("THe difference of two numbers is",n1-n2)
    else:
        raise TypeError("Please enter valid operation")
except:
    print("The error is",sys.exc_info())
finally:
    print("Good to go")
# Out:
# Enter the first digit 10
# Enter the second number -9
# Enter the operation /
# The division of two numbers is -1.1111111111111112
# Good to go
